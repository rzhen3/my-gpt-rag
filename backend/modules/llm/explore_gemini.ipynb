# %%
from google import genai
from dotenv import load_dotenv, find_dotenv
import os
from pathlib import Path

# %%
load_dotenv(Path(find_dotenv()), override=True)
gemini_key = os.getenv("GEMINI_API_KEY")
if gemini_key:
    display("loaded")
client = genai.Client()
# Out:
# 'loaded'

# %%
response = client.models.generate_content(
    model="gemini-3-flash-preview", contents = "What is the weather forecast for Ottawa for the next 3 days?"
)
print(response.text)
# Out:
# Here is the weather forecast for Ottawa for the next three days (Tuesday, May 21 – Thursday, May 23, 2024):
#
# **Tuesday, May 21**
# *   **Conditions:** Mainly sunny during the day with increasing cloudiness late in the afternoon. It will feel quite warm and humid.
# *   **Temperature:** High of 27°C (81°F), feeling like 31°C with the humidity. Low of 17°C (63°F).
# *   **Precipitation:** 30% chance of showers overnight.
#
# **Wednesday, May 22**
# *   **Conditions:** Cloudy with a high likelihood of rain. There is a strong risk of thunderstorms throughout the afternoon and evening as a cold front moves through.
# *   **Temperature:** High of 24°C (75°F), feeling like 30°C. Low of 12°C (54°F).
# *   **Precipitation:** 70% chance of showers/thunderstorms.
#
# **Thursday, May 23**
# *   **Conditions:** A mix of sun and cloud. It will be significantly cooler and less humid than the previous days.
# *   **Temperature:** High of 19°C (66°F). Low of 10°C (50°F).
# *   **Precipitation:** 10% chance of rain.
#
# **Summary:** Enjoy the heat on Tuesday, but keep an umbrella handy for Wednesday as storms are expected to move through the capital region. By Thursday, temperatures return to seasonal norms.
